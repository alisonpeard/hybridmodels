# %%
import requests
import fnmatch

# %%
url = "https://data.bris.ac.uk/data/dataset/s5hqmjcdj8yo2ibzi9b4ew3sn"
fileurl = "https://data.bris.ac.uk/datasets/s5hqmjcdj8yo2ibzi9b4ew3sn"
response = requests.get(url)
headers = response.headers
split_text = response.text.split('\n')
filtered = fnmatch.filter(split_text, '*.zip')
filenames = [x.strip() for x in filtered]

# %%
requests.get(f"{fileurl}/{filenames[0]}", headers=headers)
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File ~/miniconda3/envs/hybridmodels/lib/python3.10/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# ...

# %%
with open('tux.png', 'wb') as f:
    f.write(r.content)

# %%
# Out:
# ['N00E000-N10E010_FABDEM_V1-2.zip',
#  'N00E010-N10E020_FABDEM_V1-2.zip',
#  'N00E020-N10E030_FABDEM_V1-2.zip',
#  'N00E030-N10E040_FABDEM_V1-2.zip',
#  'N00E040-N10E050_FABDEM_V1-2.zip',
#  'N00E050-N10E060_FABDEM_V1-2.zip',
#  'N00E070-N10E080_FABDEM_V1-2.zip',
#  'N00E080-N10E090_FABDEM_V1-2.zip',
#  'N00E090-N10E100_FABDEM_V1-2.zip',
#  'N00E100-N10E110_FABDEM_V1-2.zip',
#  'N00E110-N10E120_FABDEM_V1-2.zip',
#  'N00E120-N10E130_FABDEM_V1-2.zip',
#  'N00E130-N10E140_FABDEM_V1-2.zip',
#  'N00E140-N10E150_FABDEM_V1-2.zip',
#  'N00E150-N10E160_FABDEM_V1-2.zip',
#  'N00E160-N10E170_FABDEM_V1-2.zip',
#  'N00E170-N10W180_FABDEM_V1-2.zip',
#  'N00W010-N10E000_FABDEM_V1-2.zip',
#  'N00W020-N10W010_FABDEM_V1-2.zip',
#  'N00W050-N10W040_FABDEM_V1-2.zip',
#  'N00W060-N10W050_FABDEM_V1-2.zip',
#  'N00W070-N10W060_FABDEM_V1-2.zip',
#  'N00W080-N10W070_FABDEM_V1-2.zip',
#  'N00W090-N10W080_FABDEM_V1-2.zip',
#  'N00W100-N10W090_FABDEM_V1-2.zip',
#  'N00W160-N10W150_FABDEM_V1-2.zip',
# ...

# %%
response.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/miniconda3/envs/hybridmodels/lib/python3.10/site-packages/requests/models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~/miniconda3/envs/hybridmodels/lib/python3.10/site-packages/simplejson/__init__.py:514, in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, use_decimal, allow_nan, **kw)
#     510 if (cls is None and encoding is None and object_hook is None and
#     511         parse_int is None and parse_float is None and
#     512         parse_constant is None and object_pairs_hook is None
# ...

# %%
type(text)
# Out:
# str

# %%
text
# Out:
# '<!DOCTYPE html>\n<!--[if IE 7]> <html lang="en_GB" class="ie ie7"> <![endif]-->\n<!--[if IE 8]> <html lang="en_GB" class="ie ie8"> <![endif]-->\n<!--[if IE 9]> <html lang="en_GB" class="ie9"> <![endif]-->\n<!--[if gt IE 8]><!--> <html lang="en_GB"> <!--<![endif]-->\n  <head>\n    <!--[if lte ie 8]><script type="text/javascript" src="/data/fanstatic/vendor/:version:2017-11-23T09:55:57.62/html5.min.js"></script><![endif]-->\n<link rel="stylesheet" type="text/css" href="/data/fanstatic/vendor/:version:2017-11-23T09:55:57.62/select2/select2.css" />\n<link rel="stylesheet" type="text/css" href="/data/fanstatic/css/:version:2017-11-23T09:55:57.60/main.min.css" />\n<link rel="stylesheet" type="text/css" href="/data/fanstatic/vendor/:version:2017-11-23T09:55:57.62/font-awesome/css/font-awesome.min.css" />\n\n    \n\n<!-- Global site tag (gtag.js) - Google Analytics -->\n<script async src="https://www.googletagmanager.com/gtag/js?id=UA-46034734-2"></script>\n<script>\n  window.dataLayer = wi
# ...
